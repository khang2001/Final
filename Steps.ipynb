# %% [markdown]
# # **Introduction**
#
# The project that I am doing is determining the best neighborhood in Pittsburgh by using the number of streets that has the least amount of steps avaible.
#
# Since I don't like walking far to get to places, I have chosen the best neighborhood based on much steps availble in its streets. By looking at the data in Pittsburgh steps count, I have been able to identify the ideal neighborhood to live in as someone who wouldn't prefer to walk alot.

# %% [markdown]
# ## Metrics
#
# The metric I'm using is using the number of streets that has the least amount of steps avaible in the neighborhood. This dataset is acquired from the wprdc website under the City of Pittsburgh Steps page.

# %% [markdown]
# ## Dataset

# %%
import pandas as pd
import numpy as np


data = pd.read_csv("https://data.wprdc.org/datastore/dump/43f40ca4-2211-4a12-8b4f-4d052662bb64",
                  index_col="name", 
                  parse_dates=True)

data = data.sort_values(by ='number_of_steps', )
data.iloc[:, [5,14]].head(20)
# Out:
#                                                   number_of_steps  \
# name
# Tuscola St from Ruth St to Larkfield Way                      0.0
# Eleanor St from Eccles St to Arlington Ave                    0.0
# Eleanor St from Keibs Way to Burham St                        0.0
# Eleanor St from Salisbury St to Arlington Ave                 0.0
# Birchland St from Brookline Blvd to Fitch Way                 0.0
# Piermont St from La Belle St to Sewer Way                     0.0
# Birchland St from Fitch Way to Bellaire Pl                    0.0
# Eleanor St from Wellington St to Cobden St                    0.0
# Clover St from Spring St to Elsie St                          0.0
# Andick Way from Kenberma Ave to Dagmar Ave                    0.0
# Clover St from Elsie St to Charcot St                         0.0
# Eleanor St from Burham St to Wellington St                    0.0
# Haberman Ave from Industry to Proxim Way                      0.0
# ...

# %% [markdown]
# ## Conclusion
#
# As you can see from the top 20 streets that has the least steps in Pittsburgh, you can see that South Side Slopes has the most amount of 0 steps sreets. Therefore, based on this dataset, South Side Slope is the ideal neighborhood to live in as someone who prefer not to walk
